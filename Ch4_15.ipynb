# %% [markdown]
# 15. This problem involves writing functions.

# %% [markdown]
# (a) Write a function, Power(), that prints out the result of raising 2 to the 3rd power. In other words, your function should compute 23 and print out the results.
# Hint: Recall that x**a raises x to the power a. Use the print() function to display the result.

# %%
def Power():
    result = 2 ** 3  
    print(result)  

Power()
# Out:
# 8

# %% [markdown]
# (b) Create a new function, Power2(), that allows you to pass any two numbers, x and a, and prints out the value of x**a. You can do this by beginning your function with the line
#
# def Power2(x, a):
#
# You should be able to call your function by entering, for instance,
#
# Power2(3, 8)
#
# on the command line. This should output the value of 38, namely, 6,561.

# %%
def Power2(x, a):
    result = x ** a 
    print(result)   

# Call the Power2() 
Power2(3, 8)
# Out:
# 6561

# %% [markdown]
# (c) Using the Power2() function that you just wrote, compute 103, 817, and 1313.

# %%
# Calculate 10^3 
Power2(10, 3)

# Calculate 8^17
Power2(8, 17)

# Calculate 13^13 
Power2(13, 13)
# Out:
# 1000
# 2251799813685248
# 302875106592253

# %%
def Power3(x, a):
    result = x ** a 
    return result

# %% [markdown]
# (e) Now using the Power3() function, create a plot of f(x) = x2. The x-axis should display a range of integers from 1 to 10, and the y-axis should display x2. Label the axes appropriately, and use an appropriate title for the figure. Consider displaying either the x-axis, the y-axis, or both on the log-scale. You can do this by using the ax.set_xscale() and ax.set_yscale() methods of the axes you are plotting to.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#not so sure about this one 


def Power3(x, a):
    result = x ** a 
    return result 

# Create an array of integers from 1 to 10
x_values = np.arange(1, 11)

# Calculate y values (x^2) using Power3() function
y_values = [Power3(x, 2) for x in x_values]

# Create the plot
plt.figure()
plt.plot(x_values, y_values, marker='o', linestyle='-', color='b')

# Label the axes and add a title
plt.xlabel('x')
plt.ylabel('f(x) = x^2')
plt.title('Plot of f(x) = x^2 with Logarithmic Y-Axis')

# Display the plot
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function to calculate x^2
def Power2(x):
    return x**2

# Define the range of x values
x_values = np.arange(1, 11)

# Compute the corresponding y values
y_values = Power2(x_values)

# Create the plot
fig, ax = plt.subplots()

# Plot the data
ax.plot(x_values, y_values, label="f(x) = x^2")

# Set labels and title
ax.set_xlabel("x")
ax.set_ylabel("f(x) = x^2")
ax.set_title("Plot of f(x) = x^2")

# Optionally, set one or both axes to log scale
# ax.set_xscale('log')
# ax.set_yscale('log')

# Display the legend
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# (f) Create a function, PlotPower(), that allows you to create a plot of x against x**a for a fixed a and a sequence of values of x. For instance, if you call
# PlotPower(np.arange(1, 11), 3)
# then a plot should be created with an x-axis taking on values 1,2,...,10, and a y-axis taking on values 13,23,...,103.

# %%
def PlotPower(x_values, a):
    # Calculate y values (x^a)
    y_values = [x ** a for x in x_values]

    # Create the plot
    plt.figure()
    plt.plot(x_values, y_values, marker='o', linestyle='-', color='b')

    # Label the axes and add a title
    plt.xlabel('x')
    plt.ylabel(f'x^{a}')
    plt.title(f'Plot of x^{a}')

    # Display the plot
    plt.grid(True)
    plt.show()

# %%
# Create a plot with x-axis values 1, 2, ..., 10 and y-axis values 1^3, 2^3, ..., 10^3
PlotPower(np.arange(1, 11), 3)
